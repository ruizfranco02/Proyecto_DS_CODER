# %% [markdown]
# <a href="https://colab.research.google.com/github/ruizfranco02/Proyecto_DS_CODER/blob/main/Ensayo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Avance Proyecto Final de Data Science I

# %% [markdown]
# ## Abstract
#
# ##### En la primera entrega de este proyecto analizaremos el rendimiento de los euqipos de la Liga Profesional de Futbol Argentino utilizado el dataset "afa_2015_2022_spa" basado en datos recopilados por la página PROMIEDOS. Las variables principales que rodean este dataset es el comportamiendo de los equipos locales y visitantes, teniendo consigo diferentes características con las que podemos crear las siguientes preguntas e hipotesis.
# - ¿Los equipos locales marcan más goles que los visitantes?
# - El valor del mercado tiene relación con los goles anotados
# - ¿Influyen las variables físicas en el rendimiento del equipo?
#
# ## Objetivo del proyecto
#
# ##### Desarrollar un análisis de la condición de local y visitante y que tan influyente es jugar un partido en tu estadio, así como tambien analizar que tan determinante invertir en el plantel y en las condiciones físicas de los jugadores para la mejoría del equipo.

# %%
# Carga de librerias correspondientes para leer y graficar el dataset.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga de dataset desde github

url = "https://raw.githubusercontent.com/ruizfranco02/Proyecto_DS_CODER/refs/heads/main/Datasets/afa_2015_2022_spa.csv"
df = pd.read_csv(url)
df.head()
# Out:
#             torneo  fecha  partido   equipo_local equipo_visitante  \
# 0  Campeonato 2015      1        1          Velez         Aldosivi
# 1  Campeonato 2015      1        2    Racing Club  Rosario Central
# 2  Campeonato 2015      1        3    San Lorenzo            Colon
# 3  Campeonato 2015      1        4  Gimnasia (LP)   Def y Justicia
# 4  Campeonato 2015      1        5     Godoy Cruz  San Martin (SJ)
#
#    goles_local  goles_visitante  posesion_local  tiros_arco_local  \
# 0            2                0             NaN               NaN
# 1            0                1             NaN               NaN
# 2            2                0             NaN               NaN
# 3            0                1             NaN               NaN
# 4            1                1             NaN               NaN
#
#    intentos_local  ...  proporcion_zurdos_local  valor_mercado_visitante  \
# 0             NaN  ...                 0.301887                    8.725
# 1             NaN  ...                 0.297297                   18.350
# 2             NaN  ...                 0.285714                   12.125
# 3             NaN  ...                 0.227273                   12.050
# 4             NaN  ...                 0.226415                   11.250
#
#    altura_media_visitante  edad_media_visitante  proporcion_zurdos_visitante  \
# 0                1.790370             28.100000                     0.233333
# 1                1.789333             25.608696                     0.217391
# 2                1.801026             24.948718                     0.282051
# 3                1.776889             25.460000                     0.240000
# 4                1.780000             26.153846                     0.205128
#
#    resultado      fecha_encuentro  apuesta_local  apuesta_visitante  \
# 0          L  2015-02-13 18:00:00           1.75               5.01
# 1          V  2015-02-13 21:10:00           1.80               4.82
# 2          L  2015-02-14 17:00:00           1.70               5.55
# 3          V  2015-02-14 17:00:00           2.06               3.82
# 4          E  2015-02-14 19:15:00           2.03               3.82
#
#    apuesta_empate
# 0            3.37
# 1            3.23
# 2            3.34
# 3            3.09
# 4            3.15
#
# [5 rows x 34 columns]

# %%
#Exploramos las dimensiones y columnas del dataset.

print("Dimensiones", df.shape)
print("n\Columnas")
print(df.columns.tolist())
# Out:
# Dimensiones (2821, 34)
# n\Columnas
# ['torneo', 'fecha', 'partido', 'equipo_local', 'equipo_visitante', 'goles_local', 'goles_visitante', 'posesion_local', 'tiros_arco_local', 'intentos_local', 'faltas_local', 'tiro_esquina_local', 'posesion_visitante', 'tiros_arco_visitante', 'intentos_visitante', 'faltas_visitante', 'tiro_esquina_visitante', 'amarillas_local', 'amarillas_visitante', 'rojas_local', 'rojas_visitante', 'valor_mercado_local', 'altura_media_local', 'edad_media_local', 'proporcion_zurdos_local', 'valor_mercado_visitante', 'altura_media_visitante', 'edad_media_visitante', 'proporcion_zurdos_visitante', 'resultado', 'fecha_encuentro', 'apuesta_local', 'apuesta_visitante', 'apuesta_empate']
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# <>:4: SyntaxWarning: invalid escape sequence '\C'
# /tmp/ipython-input-2496984792.py:4: SyntaxWarning: invalid escape sequence '\C'
#   print("n\Columnas")

# %% [markdown]
# El dataset cumple con las condiciones promovidas en las primeras actividades del curso, 2000 celdas y 15 columnas mínimo.

# %%
#Buscamos los valores perdidos

missing = df.isna().sum().sort_values(ascending=False)
print(missing[missing > 0])
# Out:
# intentos_local            1325
# tiros_arco_local          1325
# tiro_esquina_visitante    1325
# faltas_visitante          1325
# posesion_local            1325
# intentos_visitante        1325
# tiros_arco_visitante      1325
# posesion_visitante        1325
# tiro_esquina_local        1325
# faltas_local              1325
# amarillas_local           1313
# amarillas_visitante       1313
# rojas_local               1140
# rojas_visitante           1140
# apuesta_visitante            3
# apuesta_local                3
# apuesta_empate               3
# fecha_encuentro              3
# dtype: int64

# %% [markdown]
# ## Análisis Univariado.

# %%
# Distribución de goles del equipo local

plt.figure(figsize=(10,5))
sns.histplot(df["goles_local"], bins=20, kde=True, color="steelblue")
plt.title("Distribución de goles del equipo local")
plt.xlabel("Goles")
plt.show()

# %%
# Distribución de goles del equipo visitante.

plt.figure(figsize=(10,5))
sns.histplot(df["goles_visitante"], bins=20, kde=True, color="steelblue")
plt.title("Distribución de goles del equipo visitante")
plt.xlabel("Goles")
plt.show()
